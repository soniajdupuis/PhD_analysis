# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
settings = [
    'Only Night',
    'Only Day',
    'MODIS Aqua Values only',
    'IRCDR data only',
    'ResNet-34, lr-step=150',
    'ResNet-50, lr-step=150',
    'Run no 80 ResNet-18, lr-step=150',
    'Wild-paper-78, ResNet-18, lr-step=100',
    'Desert-surf-76, lr-step=500'
]

l1_losses = [
    1.1793115364575641,
    1.1735243770386443,
    1.1775399241983542,
    1.1595449851094162,
    1.1626778060622747,
    1.1611103519901518,
    1.1613811305200215,
    1.1623753057311987,
    1.163042774102243
]

mse_losses = [
    0.04602569679357748,
    0.045605495360783156,
    0.04599402841087795,
    0.04496723358829604,
    0.04498306407444261,
    0.04502807093104639,
    0.04487241581056924,
    0.04478331273874483,
    0.04483742622842283
]

x = np.arange(len(settings))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, l1_losses, width, label='L1 Loss', color='cornflowerblue')
bars2 = ax.bar(x + width/2, mse_losses, width, label='MSE Loss', color='salmon')

ax.set_ylabel('Loss Value', fontsize=14)
ax.set_title('Loss Comparison for Different Settings', fontsize=18)
ax.set_xticks(x)
ax.set_xticklabels(settings, fontsize=11, rotation=45, ha='right')
ax.legend(fontsize=14)

def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.3f}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10)

autolabel(bars1)
autolabel(bars2)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data (same as before)
settings = [
    'Only Night',
    'Only Day',
    'MODIS Aqua Values only',
    'IRCDR data only',
    'ResNet-34, lr-step=150',
    'ResNet-50, lr-step=150',
    'Run no 80 ResNet-18, lr-step=150',
    'Wild-paper-78, ResNet-18, lr-step=100',
    'Desert-surf-76, lr-step=500'
]

l1_losses = [
    1.1793115364575641,
    1.1735243770386443,
    1.1775399241983542,
    1.1595449851094162,
    1.1626778060622747,
    1.1611103519901518,
    1.1613811305200215,
    1.1623753057311987,
    1.163042774102243
]

mse_losses = [
    0.04602569679357748,
    0.045605495360783156,
    0.04599402841087795,
    0.04496723358829604,
    0.04498306407444261,
    0.04502807093104639,
    0.04487241581056924,
    0.04478331273874483,
    0.04483742622842283
]

x = np.arange(len(settings))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, l1_losses, width, label='L1 Loss', color='cornflowerblue')
bars2 = ax.bar(x + width/2, mse_losses, width, label='MSE Loss', color='salmon')

ax.set_ylabel('Loss Value (log scale)', fontsize=14)
ax.set_title('Loss Comparison for Different Settings (Log Scale)', fontsize=18)
ax.set_xticks(x)
ax.set_xticklabels(settings, fontsize=11, rotation=45, ha='right')
ax.set_yscale('log')  # <-- here is the log scale

ax.legend(fontsize=14)

def autolabel_log(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.3f}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 5),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10)

autolabel_log(bars1)
autolabel_log(bars2)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

settings = [
    'Only Night', 'Only Day', 'MODIS Aqua Values only', 'IRCDR data only',
    'ResNet-34, lr-step=150', 'ResNet-50, lr-step=150',
    'Run no 80 ResNet-18, lr-step=150', 'Wild-paper-78, ResNet-18, lr-step=100',
    'Desert-surf-76, lr-step=500'
]

l1_losses = np.array([
    1.1793115364575641, 1.1735243770386443, 1.1775399241983542,
    1.1595449851094162, 1.1626778060622747, 1.1611103519901518,
    1.1613811305200215, 1.1623753057311987, 1.163042774102243
])

mse_losses = np.array([
    0.04602569679357748, 0.045605495360783156, 0.04599402841087795,
    0.04496723358829604, 0.04498306407444261, 0.04502807093104639,
    0.04487241581056924, 0.04478331273874483, 0.04483742622842283
])

# Calculate difference from minimum loss (add small epsilon to avoid log(0))
epsilon = 1e-6
l1_diff = l1_losses - l1_losses.min() + epsilon
mse_diff = mse_losses - mse_losses.min() + epsilon

x = np.arange(len(settings))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, l1_diff, width, label='L1 Loss Diff', color='cornflowerblue')
bars2 = ax.bar(x + width/2, mse_diff, width, label='MSE Loss Diff', color='salmon')

ax.set_ylabel('Difference from Minimum Loss (log scale)', fontsize=14)
ax.set_title('Loss Differences Compared to Best Run (Log Scale)', fontsize=18)
ax.set_xticks(x)
ax.set_xticklabels(settings, fontsize=11, rotation=45, ha='right')
ax.set_yscale('log')

ax.legend(fontsize=14)

def autolabel_log(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2e}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 5),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10)

autolabel_log(bars1)
autolabel_log(bars2)

plt.tight_layout()
plt.show()

# %%
# for paper ('E) ResNet-50, lr-step=150') ours
import matplotlib.pyplot as plt
import numpy as np


settings = [
    'A) Night only', 'B) Day only', ' C) MODIS Aqua only', 'D) IRCDR only',
    'E) ResNet-34, lr-step=150',
    'F) ResNet-18, lr-step=150', 'G) ResNet-18, lr-step=100',
    'H) ResNet-50, lr-step=500'
]

l1_losses = np.array([
    1.1793115364575641, 1.1735243770386443, 1.1775399241983542,
    1.1645750370752068,1.1626778060622747, 
    1.1613811305200215, 1.1623753057311987, 1.163042774102243
])

mse_losses = np.array([
    0.04602569679357748, 0.045605495360783156, 0.04599402841087795,
    0.045095303279123075,0.04498306407444261, 
    0.04487241581056924, 0.04478331273874483, 0.045351269272614445
])

# Find the baseline (best) values
l1_min = 1.1611103519901518
mse_min = 0.04502807093104639

# Calculate absolute differences from baseline
l1_diff = l1_losses - l1_min
mse_diff = mse_losses - mse_min

x = np.arange(len(settings))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, l1_diff, width, label='L1 loss difference', color='cornflowerblue')
bars2 = ax.bar(x + width/2, mse_diff, width, label='MSE loss difference', color='salmon')

ax.set_ylabel('Difference from Best Loss', fontsize=14)
ax.set_title('Loss differences compared to chosen settings', fontsize=18)
ax.set_xticks(x)
ax.set_xticklabels(settings, fontsize=11, rotation=45, ha='right')

ax.legend(fontsize=14)

def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 5),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10)

autolabel(bars1)
autolabel(bars2)

plt.tight_layout()
plt.savefig('loss_differences.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

settings = [
    'Only Night', 'Only Day', 'MODIS Aqua Values only', 'IRCDR data only',
    'ResNet-34, lr-step=150', 'ResNet-50, lr-step=150',
    'Run no 80 ResNet-18, lr-step=150', 'Wild-paper-78, ResNet-18, lr-step=100',
    'Desert-surf-76, lr-step=500'
]

l1_losses = np.array([
    1.1793115364575641, 1.1735243770386443, 1.1775399241983542,
    1.1595449851094162, 1.1626778060622747, 1.1611103519901518,
    1.1613811305200215, 1.1623753057311987, 1.163042774102243
])

mse_losses = np.array([
    0.04602569679357748, 0.045605495360783156, 0.04599402841087795,
    0.04496723358829604, 0.04498306407444261, 0.04502807093104639,
    0.04487241581056924, 0.04478331273874483, 0.04483742622842283
])

# Find the baseline (best) values
l1_min = l1_losses.min()
mse_min = mse_losses.min()

# Calculate absolute differences from baseline
l1_diff = l1_losses - l1_min
mse_diff = mse_losses - mse_min

x = np.arange(len(settings))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, l1_diff, width, label='L1 Loss Diff', color='cornflowerblue')
bars2 = ax.bar(x + width/2, mse_diff, width, label='MSE Loss Diff', color='salmon')

ax.set_ylabel('Difference from Best Loss', fontsize=14)
ax.set_title('Loss Differences Compared to Best Performing Setting', fontsize=18)
ax.set_xticks(x)
ax.set_xticklabels(settings, fontsize=11, rotation=45, ha='right')

ax.legend(fontsize=14)

def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 5),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10)

autolabel(bars1)
autolabel(bars2)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

settings = [
    'Night only', 'Day only', 'MODIS Aqua only', 'IRCDR data only',
    'ResNet-34, lr-step=150', 'ResNet-50, lr-step=150',
    'ResNet-18, lr-step=150', 'ResNet-18, lr-step=100',
    'ResNet-50, lr-step=500'
]

l1_losses = np.array([
    1.1793115364575641, 1.1735243770386443, 1.1775399241983542,
    1.1645750370752068, 1.1626778060622747, 1.1611103519901518,
    1.1613811305200215, 1.1623753057311987, 1.163042774102243
])

mse_losses = np.array([
    0.04602569679357748, 0.045605495360783156, 0.04599402841087795,
    0.045095303279123075, 0.04498306407444261, 0.04502807093104639,
    0.04487241581056924, 0.04478331273874483, 0.04483742622842283
])

l1_min = l1_losses.min()
mse_min = mse_losses.min()

l1_diff = l1_losses - l1_min
mse_diff = mse_losses - mse_min

x = np.arange(len(settings))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, l1_diff, width, label='L1 Loss Diff', color='cornflowerblue')
bars2 = ax.bar(x + width/2, mse_diff, width, label='MSE Loss Diff', color='salmon')

ax.set_ylabel('Difference from Best Loss', fontsize=14)
ax.set_title('Loss Differences Compared to Best Performing Setting', fontsize=18)
ax.set_xticks(x)
ax.set_xticklabels(settings, fontsize=11, rotation=45, ha='right')

ax.set_yscale('symlog', linthresh=0.0001)  # tweak linthresh as needed
ax.yaxis.set_major_formatter(plt.ScalarFormatter())  # make ticks readable

ax.legend(fontsize=14)

def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.6f}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 5),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10)

autolabel(bars1)
autolabel(bars2)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

settings = [
    'Night only', 'Day only', 'MODIS Aqua only', 'IRCDR data only',
    'ResNet-34, lr-step=150', 'ResNet-50, lr-step=150',
    'ResNet-18, lr-step=150', 'ResNet-18, lr-step=100',
    'ResNet-50, lr-step=500'
]

l1_losses = np.array([
    1.1793115364575641, 1.1735243770386443, 1.1775399241983542,
    1.1645750370752068, 1.1626778060622747, 1.1611103519901518,
    1.1613811305200215, 1.1623753057311987, 1.163042774102243
])

mse_losses = np.array([
    0.04602569679357748, 0.045605495360783156, 0.04599402841087795,
    0.045095303279123075, 0.04498306407444261, 0.04502807093104639,
    0.04487241581056924, 0.04478331273874483, 0.04483742622842283
])

l1_min = l1_losses.min()
mse_min = mse_losses.min()

l1_diff = l1_losses - l1_min
mse_diff = mse_losses - mse_min

x = np.arange(len(settings))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, l1_diff, width, label='L1 Loss Diff', color='cornflowerblue')
bars2 = ax.bar(x + width/2, mse_diff, width, label='MSE Loss Diff', color='salmon')

ax.set_ylabel('Difference from Best Loss', fontsize=14)
ax.set_title('Loss Differences Compared to Best Performing Setting', fontsize=18)
ax.set_xticks(x)
ax.set_xticklabels(settings, fontsize=11, rotation=45, ha='right')

# No log scale applied here, y-axis is linear by default

ax.legend(fontsize=14)

def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.6f}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 5),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10)

autolabel(bars1)
autolabel(bars2)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

settings = [
    'Night only', 'Day only', 'MODIS Aqua only', 'IRCDR data only',
    'ResNet-34, lr-step=150', 'ResNet-50, lr-step=150',
    'ResNet-18, lr-step=150', 'ResNet-18, lr-step=100',
    'ResNet-50, lr-step=500'
]

l1_losses = np.array([
    1.1793115364575641, 1.1735243770386443, 1.1775399241983542,
    1.1645750370752068, 1.1626778060622747, 1.1611103519901518,
    1.1613811305200215, 1.1623753057311987, 1.163042774102243
])

mse_losses = np.array([
    0.04602569679357748, 0.045605495360783156, 0.04599402841087795,
    0.045095303279123075, 0.04498306407444261, 0.04502807093104639,
    0.04487241581056924, 0.04478331273874483, 0.04483742622842283
])

l1_min = l1_losses.min()
mse_min = mse_losses.min()

# Multiply differences by 100
l1_diff = (l1_losses - l1_min) * 100
mse_diff = (mse_losses - mse_min) * 100

x = np.arange(len(settings))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, l1_diff, width, label='L1 Loss Diff (×100)', color='cornflowerblue')
bars2 = ax.bar(x + width/2, mse_diff, width, label='MSE Loss Diff (×100)', color='salmon')

ax.set_ylabel('Difference from Best Loss (×100)', fontsize=14)
ax.set_title('Loss Differences Compared to Best Performing Setting', fontsize=18)
ax.set_xticks(x)
ax.set_xticklabels(settings, fontsize=11, rotation=45, ha='right')

ax.legend(fontsize=14)

def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 5),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10)

autolabel(bars1)
autolabel(bars2)

plt.tight_layout()
fig.savefig("loss_differences.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

settings = [
    'Only Night', 'Only Day', 'MODIS Aqua Values only', 'IRCDR data only',
    'ResNet-34, lr-step=150', 'ResNet-50, lr-step=150',
    'Run no 80 ResNet-18, lr-step=150', 'Wild-paper-78, ResNet-18, lr-step=100',
    'Desert-surf-76, lr-step=500'
]

l1_losses = np.array([
    1.1793115364575641, 1.1735243770386443, 1.1775399241983542,
    1.1595449851094162, 1.1626778060622747, 1.1611103519901518,
    1.1613811305200215, 1.1623753057311987, 1.163042774102243
])

mse_losses = np.array([
    0.04602569679357748, 0.045605495360783156, 0.04599402841087795,
    0.04496723358829604, 0.04498306407444261, 0.04502807093104639,
    0.04487241581056924, 0.04478331273874483, 0.04483742622842283
])

l1_min = l1_losses.min()
mse_min = mse_losses.min()

l1_diff = l1_losses - l1_min
mse_diff = mse_losses - mse_min

# Shift differences by +1 so minimum is 1 (log scale safe)
l1_diff_log = l1_diff + 1
mse_diff_log = mse_diff + 1

x = np.arange(len(settings))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, l1_diff_log, width, label='L1 Loss Diff + 1', color='cornflowerblue')
bars2 = ax.bar(x + width/2, mse_diff_log, width, label='MSE Loss Diff + 1', color='salmon')

ax.set_ylabel('Difference from Best Loss (log scale)', fontsize=14)
ax.set_title('Loss Differences Compared to Best Performing Setting (Log Scale)', fontsize=18)
ax.set_xticks(x)
ax.set_xticklabels(settings, fontsize=11, rotation=45, ha='right')

ax.set_yscale('log')
ax.legend(fontsize=14)

def autolabel_log(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height - 1:.4f}',  # subtract 1 to show real difference
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 5),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10)

autolabel_log(bars1)
autolabel_log(bars2)

plt.tight_layout()
plt.show()
