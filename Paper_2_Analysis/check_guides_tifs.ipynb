# %%
import xarray as xr

# %%
trial =xr.open_dataset('/scratch/sdupuis/patch_AVN12_1991_v11.0_fiery-waterfall_100_100_1991-09-18_NIGHT_trial.tif'
, engine="rasterio")

# %%
trial
# Out:
# <xarray.Dataset> Size: 15MB
# Dimensions:      (band: 1, x: 1920, y: 1920)
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB -179.9 -179.9 -179.9 ... -160.8 -160.8 -160.7
#   * y            (y) float64 15kB 84.0 83.99 83.98 83.97 ... 64.83 64.82 64.81
#     spatial_ref  int64 8B ...
# Data variables:
#     band_data    (band, y, x) float32 15MB ...

# %%
trial['band_data'].plot(vmin=220, vmax=300);

# %%
guide = xr.open_dataset('/scratch/sdupuis/patch_guide_100_100.tif'
, engine="rasterio")

# %%
guide
# Out:
# <xarray.Dataset> Size: 44MB
# Dimensions:      (band: 3, x: 1920, y: 1920)
# Coordinates:
#   * band         (band) int64 24B 1 2 3
#   * x            (x) float64 15kB -179.9 -179.9 -179.9 ... -160.8 -160.8 -160.7
#   * y            (y) float64 15kB 84.0 83.99 83.98 83.97 ... 64.83 64.82 64.81
#     spatial_ref  int64 8B ...
# Data variables:
#     band_data    (band, y, x) float32 44MB ...

# %%
guide = guide.reindex(y=list(reversed(guide.y)))

# %%
guide['band_data'].sel(band=1).plot();
