# %%
import xarray as xr

# %%
### ALE

ale =xr.open_mfdataset('/mnt/data7/nfs4/avh_ndvi/sdupuis/LST_dwnscl_BSRN/NC/DAY/2004/AVN16/LST_AVN16_ALE__v.11.0__2004-*_DAY.nc')

# %%
ale
# Out:
# <xarray.Dataset> Size: 47GB
# Dimensions:            (time: 230, lat: 1920, lon: 1920)
# Coordinates:
#   * lon                (lon) float64 15kB -72.35 -72.34 -72.33 ... -53.17 -53.16
#   * lat                (lat) float64 15kB 64.81 64.81 64.83 ... 83.97 83.98 84.0
#   * time               (time) datetime64[ns] 2kB 2004-05-16 ... 2004-12-31
# Data variables:
#     LST                (time, lat, lon) float64 7GB dask.array<chunksize=(1, 1920, 1920), meta=np.ndarray>
#     scanline_time_asc  (time, lat, lon) float64 7GB dask.array<chunksize=(1, 1920, 1920), meta=np.ndarray>
#     LST_GAC            (time, lat, lon) float64 7GB dask.array<chunksize=(1, 1920, 1920), meta=np.ndarray>
#     satzen             (time, lat, lon) float64 7GB dask.array<chunksize=(1, 1920, 1920), meta=np.ndarray>
#     sunzen             (time, lat, lon) float64 7GB dask.array<chunksize=(1, 1920, 1920), meta=np.ndarray>
# ...

# %%
ale['LST'].sel(time=slice('2004-07-16', '2004-07-30'), lat=slice(80, 84), lon=slice(-65, -60)).plot(x="lon", y="lat", col="time", col_wrap=6);

# %%
ale =xr.open_mfdataset('/mnt/data7/nfs4/avh_ndvi/sdupuis/LST_dwnscl_BSRN/NC/DAY/2007/AVN17/LST_AVN17_ALE__v.11.0__2007-*_DAY.nc')

# %%
ale['LST'].sel(time=slice('2007-06-16', '2007-06-30'), lat=slice(80, 84), lon=slice(-65, -60)).plot(x="lon", y="lat", col="time", col_wrap=6);

# %%
## NSA
nsa =xr.open_mfdataset('/mnt/data7/nfs4/avh_ndvi/sdupuis/LST_dwnscl_BSRN/NC/DAY/2007/AVN17/LST_AVN17_NSA__v.11.0__2007-*_DAY.nc')

# %%
nsa
# Out:
# <xarray.Dataset> Size: 75GB
# Dimensions:             (time: 365, lat: 1920, lon: 1920)
# Coordinates:
#   * lon                 (lon) float64 15kB -162.0 -162.0 ... -142.8 -142.8
#   * lat                 (lat) float64 15kB 64.81 64.81 64.83 ... 83.98 84.0
#   * time                (time) datetime64[ns] 3kB 2007-01-01 ... 2007-12-31
# Data variables:
#     LST                 (time, lat, lon) float64 11GB dask.array<chunksize=(1, 1920, 1920), meta=np.ndarray>
#     scanline_time_desc  (time, lat, lon) float64 11GB dask.array<chunksize=(1, 1920, 1920), meta=np.ndarray>
#     LST_GAC             (time, lat, lon) float64 11GB dask.array<chunksize=(1, 1920, 1920), meta=np.ndarray>
#     satzen              (time, lat, lon) float64 11GB dask.array<chunksize=(1, 1920, 1920), meta=np.ndarray>
#     sunzen              (time, lat, lon) float64 11GB dask.array<chunksize=(1, 1920, 1920), meta=np.ndarray>
# ...

# %%
nsa['LST'].sel(time=slice('2007-06-16', '2007-06-30'), lat=slice(70, 72), lon=slice(-160, -155)).plot(x="lon", y="lat", col="time", col_wrap=6);

# %%
## NYA

# %%
test = xr.open_dataset('/mnt/data7/nfs4/avh_ndvi/sdupuis/LST_dwnscl_BSRN/NC/DAY/2014/AVMEA/LST_AVMEA_NYA__v.11.0__2014-01-01_DAY.nc')

# %%
test
# Out:
# <xarray.Dataset> Size: 206MB
# Dimensions:             (lon: 1920, lat: 1920, time: 1)
# Coordinates:
#   * lon                 (lon) float64 15kB -0.63 -0.62 -0.61 ... 18.55 18.56
#   * lat                 (lat) float64 15kB 64.81 64.81 64.83 ... 83.98 84.0
#   * time                (time) datetime64[ns] 8B 2014-01-01
# Data variables:
#     LST                 (time, lat, lon) float64 29MB ...
#     scanline_time_desc  (time, lat, lon) float64 29MB ...
#     LST_GAC             (time, lat, lon) float64 29MB ...
#     satzen              (time, lat, lon) float64 29MB ...
#     sunzen              (time, lat, lon) float64 29MB ...
#     test_mae            (lat, lon) float64 29MB ...
#     r2                  (lat, lon) float64 29MB ...
#     spatial_ref         int64 8B ...

# %%
test['LST'].plot();

# %%
# open more than one !

# %%
tik= xr.open_dataset('/mnt/data7/nfs4/avh_ndvi/sdupuis/LST_dwnscl_Arctic/output_patches/2010/AVMEA/patch_SI_AVMEA_2010_v11.0_all_arctic_fiery-waterfall_87_174_2010-02-13__DAY.tif')

# %%
tik
# Out:
# <xarray.Dataset> Size: 15MB
# Dimensions:      (band: 1, x: 1920, y: 1920)
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 123.0 123.0 123.0 123.0 ... 142.2 142.2 142.2
#   * y            (y) float64 15kB 84.0 83.99 83.98 83.97 ... 64.83 64.82 64.81
#     spatial_ref  int64 8B ...
# Data variables:
#     band_data    (band, y, x) float32 15MB ...
