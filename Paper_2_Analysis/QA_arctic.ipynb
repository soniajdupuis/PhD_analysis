# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
#read GAC data
gac = xr.open_dataset('/mnt/data7/nfs4/avh_lst/sdupuis/EUSTACE/All_Arctic/1988/AVN09/LST_AVN09_All_Arctic__v.11.0__19880102_DAY.nc')

# %%
gac
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 800, lon: 7200, time: 1)
# Coordinates:
#   * lat          (lat) float32 50.03 50.08 50.12 50.17 ... 89.88 89.93 89.97
#   * lon          (lon) float32 -180.0 -179.9 -179.9 -179.8 ... 179.9 179.9 180.0
#     band         int64 ...
#     spatial_ref  int64 ...
#   * time         (time) datetime64[ns] 1988-01-02
# Data variables:
#     LST          (lat, lon, time) float32 ...
#     satzen       (time, lat, lon) float32 ...
#     sunzen       (time, lat, lon) float32 ...
#     scan_time    (time, lat, lon) float32 ...
#     test_mae     (lat, lon) float32 ...
#     r2           (lat, lon) float32 ...

# %%
test =xr.open_dataset('/mnt/data7/nfs4/avh_ndvi/sdupuis/LST_dwnscl_Arctic/TIF/day_combined/2010/AVN19/CB_Arctic_AVN19_2010_dwn_20100802_fiery-waterfall_v11.0_DAY.tif'
, engine="rasterio")

# %%
test
# Out:
# <xarray.Dataset>
# Dimensions:      (band: 1, x: 35987, y: 3400)
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -179.9 -179.9 -179.9 -179.9 ... 179.9 179.9 179.9
#   * y            (y) float64 84.0 83.99 83.98 83.97 ... 50.04 50.03 50.02 50.01
#     spatial_ref  int64 ...
# Data variables:
#     band_data    (band, y, x) float64 ...

# %%
selec = test.sel(x=slice(-150,-120), y=slice(75,60))

# %%
selec
# Out:
# <xarray.Dataset>
# Dimensions:      (band: 1, x: 3001, y: 1500)
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -150.0 -150.0 -150.0 ... -120.0 -120.0 -120.0
#   * y            (y) float64 75.0 74.99 74.98 74.97 ... 60.04 60.03 60.02 60.01
#     spatial_ref  int64 ...
# Data variables:
#     band_data    (band, y, x) float64 ...

# %%
selec['band_data'].plot(vmin=200);

# %%
selec = test.sel(x=slice(-50,-30), y=slice(75,60))
selec['band_data'].plot(vmin=190, vmax=350);

# %%
selec = test.sel(x=slice(35,70), y=slice(60,50))
selec['band_data'].plot(vmin=190, vmax=350);

# %%
selec = test.sel(x=slice(160,180), y=slice(70,60))
selec['band_data'].plot();

# %%
selec = test.sel(x=slice(120,140), y=slice(80,70))
selec['band_data'].plot();

# %%
selec = test.sel(x=slice(120,140), y=slice(70,60))
selec['band_data'].plot();

# %%
selec = test.sel(x=slice(120,140), y=slice(60,50))
selec['band_data'].plot();

# %%
selec = test.sel(x=slice(-130,-120), y=slice(55,50))

# %%
selec
# Out:
# <xarray.Dataset>
# Dimensions:      (band: 1, x: 1001, y: 500)
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -130.0 -130.0 -130.0 ... -120.0 -120.0 -120.0
#   * y            (y) float64 55.0 54.99 54.98 54.97 ... 50.04 50.03 50.02 50.01
#     spatial_ref  int64 ...
# Data variables:
#     band_data    (band, y, x) float64 ...

# %%
selec = test.sel(x=slice(101,104), y=slice(55,50))
selec['band_data'].plot();

# %%
gac['LST'].sel(lon=slice(101,104), lat=slice(50,55)).plot(vmin=220)

# %%
#get BT data
bt = xr.open_dataset('/mnt/data3/nfs4/cci_snow_3/composites/beta/CAC/AVN09/1988/CACin19880103000000323AVN0901GL.nc')

# %%
bt['bt_tir120_asc'].sel(lon=slice(101,104), lat=slice(50,55)).plot()

# %%
# potential problem: AVN09 1988 : 01-01
